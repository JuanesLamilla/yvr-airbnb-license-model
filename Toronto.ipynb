# %% [markdown]
# ## Running the Treatment group City - Toronto

# %% [markdown]
# **By running the Difference-in-Difference analysis, we need one control group city, this city should have following features:**
#
# 1. **Similar to the treatment group city**: The control city should have similar characteristics to the treatment city, such as population size, economic structure, and demographic profile.
#
# 2. **Not affected by the treatment**: The control city should not be directly affected by the policy changes being studied, ensuring that any differences observed can be attributed to the treatment rather than other factors.
#
# 3. **Stable over time**: The control city should have a stable trend in the outcome variable of interest before the treatment, allowing for a clear comparison with the treatment city.
#
# 4. **Geographical proximity**: Ideally, the control city should be geographically close to the treatment city to minimize external influences and ensure that both cities are subject to similar regional economic conditions, including the peak time and seasonality of the year to the STR market.
#
# Here, we use the Vancouver city as the control group city, which is similar to the treatment group city (Toronto) in terms of population size, economic structure, and demographic profile. As illustrated in the following graph.

# %%
# Load libraries
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm

sns.set_style('darkgrid')
import math
from sklearn.linear_model import LogisticRegression
from scipy import stats

import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

from license_model import LicenseModel
# Out:
# c:\Users\SBH\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# ### Iteratively run the monthly data for the control group city and get the results coefficients

# %%
import pandas as pd
import os
import numpy as np
from license_model import LicenseModel

# 设置参数
BASE_DIR = os.path.join('data', 'Toronto')
MONTHS = pd.date_range(start='2024-06-01', end='2025-04-01', freq='MS').strftime('%Y%m').tolist()
MIN_NIGHTS_FOR_LICENSE = 29
LICENSE_REGEX_PATTERN = r'.*?(\d{2}[-\s]?\d{3}[-\s]?\d{3}).*?'

# %%
# Step1 : Process each month's data and collect independent variables
all_variables = set()
protected = []

for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Toronto',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN,
            protected_columns=protected
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()

        variables = model.logit_model.result.params.index.tolist()
        all_variables.update([v for v in variables if 'neighbourhood' not in v.lower()])

        print(f"[✓] Processed variables for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")

# Step2 : Create a DataFrame to hold coefficients for each month
Vancouver_airbnb_coefficients = pd.DataFrame(index=sorted(all_variables), columns=MONTHS)

# Step3 : Collect coefficients for each month
for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Toronto',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()

        coef_series = model.logit_model.result.params
        coef_series = coef_series[~coef_series.index.str.contains('neighbourhood', case=False, na=False)]

        for var in coef_series.index:
            Vancouver_airbnb_coefficients.loc[var, month] = coef_series[var]

        print(f"[✓] Coefficients recorded for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")


# Step4 : Collect model performance metrics for each month
model_performance_summary = []

for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Toronto',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()
        model.logit_model.evaluate_model(selected_threshold=0.5, print_info=False)

        auc = model.logit_model.auc
        acc = model.logit_model.accuracy
        pseudo_r2 = model.logit_model.result.prsquared
        one_in_ten = model.does_data_follow_one_in_ten_rule(print_info=False)
        n_predictors = model.logit_model.X_train.shape[1]
        illegal_prop = 1 - model.listings_df['legal_listing'].mean()

        model_performance_summary.append({
            'month': month,
            'AUC': auc,
            'Accuracy': acc,
            'Pseudo_R2': pseudo_r2,
            'Num_Predictors': n_predictors,
            'OneInTenRule': one_in_ten,
            'IllegalProp': illegal_prop
        })

        print(f"[✓] Model performance recorded for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000005
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# [!] Warning during outlier removal for 202406: need covariance of parameters for computing (unnormalized) covariances
# Optimization terminated successfully.
#          Current function value: 0.000006
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                13249
# Model:                          Logit   Df Residuals:                    13094
# Method:                           MLE   Df Model:                          154
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                     inf
# Time:                        02:10:21   Log-Likelihood:              -0.073776
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# host_response_time                                            -0.0785        nan        nan        nan         nan         nan
# host_is_superhost                                             -0.0310        nan        nan        nan         nan         nan
# host_total_listings_count                                     -0.4608        nan        nan        nan         nan         nan
# accommodates                                                  -0.7438        nan        nan        nan         nan         nan
# bedrooms                                                      -0.3803        nan        nan        nan         nan         nan
# minimum_nights                                                -1.5174        nan        nan        nan         nan         nan
# availability_30                                               -0.0775        nan        nan        nan         nan         nan
# availability_365                                              -0.6722        nan        nan        nan         nan         nan
# number_of_reviews                                             -0.6057        nan        nan        nan         nan         nan
# number_of_reviews_ltm                                         -0.4137        nan        nan        nan         nan         nan
# number_of_reviews_l30d                                        -0.0248        nan        nan        nan         nan         nan
# instant_bookable                                              -0.0314        nan        nan        nan         nan         nan
# calculated_host_listings_count_entire_homes                   -0.1947        nan        nan        nan         nan         nan
# calculated_host_listings_count_private_rooms                  -0.1272        nan        nan        nan         nan         nan
# calculated_host_listings_count_shared_rooms                   -0.0017        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Agincourt South-Malvern West           -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Alderwood                              -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Annex                                  -0.0034        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Banbury-Don Mills                      -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bathurst Manor                         -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bay Street Corridor                    -0.0073        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Village                        -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Woods-Steeles                  -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bedford Park-Nortown                   -0.0009        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Beechborough-Greenbrook             -2.839e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bendale                                -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Birchcliffe-Cliffside                  -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Black Creek                         -4.395e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Blake-Jones                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Briar Hill-Belgravia                   -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bridle Path-Sunnybrook-York Mills   -3.431e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Broadview North                        -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Brookhaven-Amesbury                 -5.622e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Cabbagetown-South St.James Town        -0.0052        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Caledonia-Fairbank                  -2.679e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Casa Loma                              -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Centennial Scarborough              -8.309e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Church-Yonge Corridor                  -0.0099        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Clairlea-Birchmount                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Clanton Park                           -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Cliffcrest                             -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Corso Italia-Davenport                 -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Danforth                               -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Danforth East York                     -0.0036        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Don Valley Village                     -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dorset Park                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dovercourt-Wallace Emerson-Junction    -0.0034        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Downsview-Roding-CFB                   -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dufferin Grove                         -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_East End-Danforth                      -0.0013        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Edenbridge-Humber Valley               -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Eglinton East                       -3.695e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Elms-Old Rexdale                    -2.875e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Englemount-Lawrence                 -7.047e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Eringate-Centennial-West Deane         -0.0014        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Etobicoke West Mall                    -0.0011        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Flemingdon Park                        -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Forest Hill North                      -0.0035        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Forest Hill South                   -8.297e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Glenfield-Jane Heights                 -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Greenwood-Coxwell                      -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Guildwood                              -0.0035        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Henry Farm                             -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_High Park North                        -0.0075        nan        nan        nan         nan         nan
# neighbourhood_cleansed_High Park-Swansea                      -0.0037        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Highland Creek                         -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Hillcrest Village                      -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humber Heights-Westmount            -8.019e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humber Summit                       -5.111e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humbermede                          -6.726e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humewood-Cedarvale                     -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Ionview                                -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Islington-City Centre West             -0.0053        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Junction Area                          -0.0059        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Keelesdale-Eglinton West            -6.345e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kennedy Park                        -3.967e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kensington-Chinatown                   -0.0032        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsview Village-The Westway       -2.593e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsway South                         -0.0015        nan        nan        nan         nan         nan
# neighbourhood_cleansed_L'Amoreaux                             -0.0006        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lambton Baby Point                  -7.937e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lansing-Westgate                       -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park North                    -0.0017        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park South                    -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Leaside-Bennington                     -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Little Portugal                        -0.0042        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Long Branch                            -0.0008        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Malvern                                -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Maple Leaf                          -6.073e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Markland Wood                        -5.43e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Milliken                            -5.248e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mimico (includes Humber Bay Shores)    -0.0012        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Morningside                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Moss Park                              -0.0021        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Dennis                           -0.0012        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Olive-Silverstone-Jamestown   -1.941e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant East                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant West                    -0.0043        nan        nan        nan         nan         nan
# neighbourhood_cleansed_New Toronto                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook East                       -0.0077        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook West                       -0.0008        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Niagara                                -0.0115        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North Riverdale                        -0.0053        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North St.James Town                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_O'Connor-Parkview                      -0.0050        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakridge                            -7.101e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakwood Village                        -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Old East York                          -0.0019        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Palmerston-Little Italy                -0.0055        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Parkwoods-Donalda                      -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pelmo Park-Humberlea                   -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Playter Estates-Danforth               -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pleasant View                          -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Princess-Rosethorn                     -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Regent Park                            -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rexdale-Kipling                     -9.135e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rockcliffe-Smythe                      -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Roncesvalles                           -0.0019        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rosedale-Moore Park                    -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rouge                                  -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Runnymede-Bloor West Village           -0.0009        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rustic                              -4.472e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Scarborough Village                 -8.312e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Parkdale                         -0.0049        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Riverdale                        -0.0012        nan        nan        nan         nan         nan
# neighbourhood_cleansed_St.Andrew-Windfields                -3.971e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Steeles                                -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Stonegate-Queensway                    -0.0034        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Tam O'Shanter-Sullivan                 -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Taylor-Massey                          -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_The Beaches                            -0.0047        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thistletown-Beaumond Heights           -0.0028        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thorncliffe Park                    -1.157e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Trinity-Bellwoods                      -0.0119        nan        nan        nan         nan         nan
# neighbourhood_cleansed_University                             -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Victoria Village                    -2.409e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Hill                              -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Humber-Clairville                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Westminster-Branson                 -7.837e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston                                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston-Pellam Park                     -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wexford/Maryvale                       -0.0041        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale East                        -0.0024        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale West                        -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowridge-Martingrove-Richview       -0.0006        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woburn                                 -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine Corridor                      -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine-Lumsden                       -0.0008        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wychwood                               -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-Eglinton                         -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-St.Clair                         -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_York University Heights                -0.0051        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yorkdale-Glen Park                     -0.0003        nan        nan        nan         nan         nan
# room_type_Private room                                        -0.0748        nan        nan        nan         nan         nan
# room_type_Shared room                                         -0.0010        nan        nan        nan         nan         nan
# ==============================================================================================================================
#
# Possibly complete quasi-separation: A fraction 1.00 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# [✓] Processed variables for 202406
# Optimization terminated successfully.
#          Current function value: 0.000005
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# [!] Warning during outlier removal for 202407: need covariance of parameters for computing (unnormalized) covariances
# Optimization terminated successfully.
#          Current function value: 0.000005
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                13127
# Model:                          Logit   Df Residuals:                    12971
# Method:                           MLE   Df Model:                          155
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                     inf
# Time:                        02:11:40   Log-Likelihood:              -0.068558
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# host_response_time                                            -0.1075        nan        nan        nan         nan         nan
# host_is_superhost                                             -0.0549        nan        nan        nan         nan         nan
# host_total_listings_count                                     -0.4773        nan        nan        nan         nan         nan
# accommodates                                                  -0.7559        nan        nan        nan         nan         nan
# bedrooms                                                      -0.3784        nan        nan        nan         nan         nan
# minimum_nights                                                -1.3462        nan        nan        nan         nan         nan
# availability_30                                               -0.0624        nan        nan        nan         nan         nan
# availability_90                                               -0.2082        nan        nan        nan         nan         nan
# availability_365                                              -0.6716        nan        nan        nan         nan         nan
# number_of_reviews                                             -0.6700        nan        nan        nan         nan         nan
# number_of_reviews_ltm                                         -0.4389        nan        nan        nan         nan         nan
# number_of_reviews_l30d                                        -0.0655        nan        nan        nan         nan         nan
# instant_bookable                                              -0.0429        nan        nan        nan         nan         nan
# calculated_host_listings_count_entire_homes                   -0.2548        nan        nan        nan         nan         nan
# calculated_host_listings_count_private_rooms                  -0.0837        nan        nan        nan         nan         nan
# calculated_host_listings_count_shared_rooms                   -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Agincourt South-Malvern West           -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Alderwood                              -0.0028        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Annex                                  -0.0030        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Banbury-Don Mills                      -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bathurst Manor                         -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bay Street Corridor                    -0.0010        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Village                     -6.707e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Woods-Steeles               -5.132e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bedford Park-Nortown                   -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Beechborough-Greenbrook             -2.563e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bendale                             -9.191e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Birchcliffe-Cliffside                  -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Black Creek                         -7.337e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Blake-Jones                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Briar Hill-Belgravia                   -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bridle Path-Sunnybrook-York Mills    -3.56e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Broadview North                        -0.0011        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Brookhaven-Amesbury                 -5.544e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Cabbagetown-South St.James Town        -0.0010        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Caledonia-Fairbank                  -5.303e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Casa Loma                              -0.0010        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Centennial Scarborough               -2.06e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Church-Yonge Corridor                  -0.0084        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Clairlea-Birchmount                    -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Clanton Park                           -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Cliffcrest                             -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Corso Italia-Davenport                 -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Danforth                               -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Danforth East York                     -0.0026        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Don Valley Village                     -0.0042        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dorset Park                         -9.613e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dovercourt-Wallace Emerson-Junction    -0.0053        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Downsview-Roding-CFB                   -0.0097        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dufferin Grove                         -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_East End-Danforth                      -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Edenbridge-Humber Valley            -6.714e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Eglinton East                       -3.358e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Elms-Old Rexdale                       -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Englemount-Lawrence                 -5.452e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Eringate-Centennial-West Deane      -5.351e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Etobicoke West Mall                 -6.692e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Flemingdon Park                     -6.295e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Forest Hill North                      -0.0017        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Forest Hill South                      -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Glenfield-Jane Heights              -9.944e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Greenwood-Coxwell                      -0.0031        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Guildwood                              -0.0036        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Henry Farm                          -8.394e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_High Park North                        -0.0040        nan        nan        nan         nan         nan
# neighbourhood_cleansed_High Park-Swansea                      -0.0014        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Highland Creek                      -6.479e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Hillcrest Village                   -6.751e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humber Heights-Westmount            -8.968e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humber Summit                       -5.179e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humbermede                          -7.121e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humewood-Cedarvale                     -0.0020        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Ionview                                -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Islington-City Centre West             -0.0061        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Junction Area                          -0.0056        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Keelesdale-Eglinton West            -1.939e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kennedy Park                        -1.094e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kensington-Chinatown                   -0.0014        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsview Village-The Westway       -7.807e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsway South                      -3.376e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_L'Amoreaux                             -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lambton Baby Point                  -9.871e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lansing-Westgate                       -0.0046        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park North                    -0.0017        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park South                    -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Leaside-Bennington                     -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Little Portugal                        -0.0061        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Long Branch                          -6.75e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Malvern                                -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Maple Leaf                          -7.821e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Markland Wood                       -3.237e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Milliken                            -4.522e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mimico (includes Humber Bay Shores)    -0.0039        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Morningside                          -9.37e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Moss Park                              -0.0010        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Dennis                           -0.0021        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Olive-Silverstone-Jamestown   -1.802e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant East                    -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant West                    -0.0038        nan        nan        nan         nan         nan
# neighbourhood_cleansed_New Toronto                         -9.305e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook East                       -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook West                       -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Niagara                                -0.0143        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North Riverdale                        -0.0052        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North St.James Town                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_O'Connor-Parkview                      -0.0048        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakridge                               -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakwood Village                        -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Old East York                          -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Palmerston-Little Italy                -0.0023        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Parkwoods-Donalda                      -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pelmo Park-Humberlea                -7.143e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Playter Estates-Danforth               -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pleasant View                          -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Princess-Rosethorn                  -8.276e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Regent Park                            -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rexdale-Kipling                     -8.803e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rockcliffe-Smythe                      -0.0033        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Roncesvalles                           -0.0014        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rosedale-Moore Park                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rouge                                  -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Runnymede-Bloor West Village           -0.0006        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rustic                               -6.15e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Scarborough Village                 -6.608e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Parkdale                         -0.0045        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Riverdale                        -0.0050        nan        nan        nan         nan         nan
# neighbourhood_cleansed_St.Andrew-Windfields                   -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Steeles                                -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Stonegate-Queensway                    -0.0086        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Tam O'Shanter-Sullivan                 -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Taylor-Massey                          -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_The Beaches                            -0.0026        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thistletown-Beaumond Heights           -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thorncliffe Park                    -3.436e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Trinity-Bellwoods                      -0.0132        nan        nan        nan         nan         nan
# neighbourhood_cleansed_University                             -0.0024        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Victoria Village                    -2.038e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Hill                              -0.0014        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Humber-Clairville                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Westminster-Branson                    -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston                                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston-Pellam Park                     -0.0040        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wexford/Maryvale                       -0.0008        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale East                        -0.0016        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale West                        -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowridge-Martingrove-Richview    -9.852e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woburn                                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine Corridor                      -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine-Lumsden                       -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wychwood                               -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-Eglinton                         -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-St.Clair                         -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_York University Heights                -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yorkdale-Glen Park                     -0.0046        nan        nan        nan         nan         nan
# room_type_Private room                                        -0.0398        nan        nan        nan         nan         nan
# room_type_Shared room                                      -6.105e-05        nan        nan        nan         nan         nan
# ==============================================================================================================================
#
# Possibly complete quasi-separation: A fraction 1.00 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# [✓] Processed variables for 202407
# Optimization terminated successfully.
#          Current function value: 0.000004
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
# [!] Warning during outlier removal for 202408: need covariance of parameters for computing (unnormalized) covariances
# Optimization terminated successfully.
#          Current function value: 0.000004
#          Iterations: 14
#          Function evaluations: 15
#          Gradient evaluations: 15
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                13187
# Model:                          Logit   Df Residuals:                    13032
# Method:                           MLE   Df Model:                          154
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                     inf
# Time:                        02:12:56   Log-Likelihood:              -0.053807
# converged:                       True   LL-Null:                        0.0000
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ==============================================================================================================================
#                                                                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------------
# host_response_time                                            -0.0980        nan        nan        nan         nan         nan
# host_is_superhost                                             -0.0299        nan        nan        nan         nan         nan
# host_total_listings_count                                     -0.4232        nan        nan        nan         nan         nan
# accommodates                                                  -0.7006        nan        nan        nan         nan         nan
# bedrooms                                                      -0.3558        nan        nan        nan         nan         nan
# minimum_nights                                                -1.2294        nan        nan        nan         nan         nan
# availability_30                                               -0.0638        nan        nan        nan         nan         nan
# availability_90                                               -0.2132        nan        nan        nan         nan         nan
# availability_365                                              -0.6930        nan        nan        nan         nan         nan
# number_of_reviews                                             -0.6431        nan        nan        nan         nan         nan
# number_of_reviews_ltm                                         -0.4037        nan        nan        nan         nan         nan
# number_of_reviews_l30d                                        -0.0661        nan        nan        nan         nan         nan
# instant_bookable                                              -0.0245        nan        nan        nan         nan         nan
# calculated_host_listings_count_entire_homes                   -0.2128        nan        nan        nan         nan         nan
# calculated_host_listings_count_private_rooms                  -0.0814        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Agincourt South-Malvern West           -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Alderwood                              -0.0025        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Annex                                  -0.0013        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Banbury-Don Mills                    -8.38e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bathurst Manor                         -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bay Street Corridor                    -0.0012        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Village                       -8.6e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bayview Woods-Steeles               -5.887e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Bedford Park-Nortown                 -8.39e-05        nan        nan        nan         nan         nan
# ...
# neighbourhood_cleansed_Humbermede                          -4.815e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Humewood-Cedarvale                     -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Ionview                             -9.128e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Islington-City Centre West             -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Junction Area                          -0.0065        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Keelesdale-Eglinton West            -2.721e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kennedy Park                           -0.0005        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kensington-Chinatown                   -0.0006        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsview Village-The Westway       -2.896e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kingsway South                      -5.205e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_L'Amoreaux                             -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lambton Baby Point                  -8.839e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lansing-Westgate                       -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park North                    -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Lawrence Park South                    -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Leaside-Bennington                     -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Little Portugal                        -0.0033        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Long Branch                         -6.068e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Malvern                             -8.327e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Maple Leaf                           -5.79e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Markland Wood                        -3.59e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Milliken                            -4.129e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mimico (includes Humber Bay Shores)    -0.0007        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Morningside                         -8.483e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Moss Park                              -0.0045        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Dennis                        -8.317e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Olive-Silverstone-Jamestown   -1.782e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant East                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant West                    -0.0004        nan        nan        nan         nan         nan
# neighbourhood_cleansed_New Toronto                         -8.758e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook East                       -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Newtonbrook West                       -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Niagara                                -0.0036        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North Riverdale                        -0.0050        nan        nan        nan         nan         nan
# neighbourhood_cleansed_North St.James Town                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_O'Connor-Parkview                      -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakridge                            -7.784e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakwood Village                        -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Old East York                       -7.605e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Palmerston-Little Italy                -0.0066        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Parkwoods-Donalda                      -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pelmo Park-Humberlea                -9.605e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Playter Estates-Danforth               -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Pleasant View                       -8.809e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Princess-Rosethorn                  -8.866e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Regent Park                            -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rexdale-Kipling                     -7.824e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rockcliffe-Smythe                   -9.377e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Roncesvalles                           -0.0054        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rosedale-Moore Park                    -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rouge                               -7.205e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Runnymede-Bloor West Village           -0.0049        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Rustic                              -3.852e-06        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Scarborough Village                 -5.905e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Parkdale                         -0.0006        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Riverdale                        -0.0126        nan        nan        nan         nan         nan
# neighbourhood_cleansed_St.Andrew-Windfields                -1.252e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Steeles                                -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Stonegate-Queensway                    -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Tam O'Shanter-Sullivan              -4.488e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Taylor-Massey                          -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_The Beaches                            -0.0052        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thistletown-Beaumond Heights        -5.861e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Thorncliffe Park                       -0.0009        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Trinity-Bellwoods                      -0.0051        nan        nan        nan         nan         nan
# neighbourhood_cleansed_University                             -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Victoria Village                    -1.011e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Hill                           -5.161e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Humber-Clairville                 -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Westminster-Branson                 -9.647e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston                                 -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Weston-Pellam Park                     -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wexford/Maryvale                       -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale East                        -0.0022        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowdale West                        -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Willowridge-Martingrove-Richview    -8.172e-05        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woburn                                 -0.0002        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine Corridor                      -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Woodbine-Lumsden                       -0.0023        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Wychwood                               -0.0074        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-Eglinton                         -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yonge-St.Clair                         -0.0001        nan        nan        nan         nan         nan
# neighbourhood_cleansed_York University Heights                -0.0003        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Yorkdale-Glen Park                     -0.0001        nan        nan        nan         nan         nan
# room_type_Private room                                        -0.0218        nan        nan        nan         nan         nan
# room_type_Shared room                                      -4.173e-06        nan        nan        nan         nan         nan
# ==============================================================================================================================
#
# Possibly complete quasi-separation: A fraction 1.00 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# [✓] Processed variables for 202502
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 19
#      11 try:
#      12     model = LicenseModel(
#      13         city='Toronto',
#      14         input_file=input_file,
#    (...)
#      17         protected_columns=protected
#      18     )
# ---> 19     model.run_initial_setup()
#      20     violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
#      21     for var in violating_vars:
#
# File c:\Users\SBH\OneDrive - University College London\【UCL-MSc】\#CASA0007__QuantitativeMethods\ASSESSMENT\GroupworkPresentation\yvr-airbnb-license-model\license_model.py:532, in LicenseModel.run_initial_setup(self, print_info)
#     530 self.one_hot_encode_columns(print_info=print_info)
#     531 self.remove_separation(print_info=print_info)
# --> 532 self.detect_and_remove_multicollinearity(print_info=print_info)
#
# File c:\Users\SBH\OneDrive - University College London\【UCL-MSc】\#CASA0007__QuantitativeMethods\ASSESSMENT\GroupworkPresentation\yvr-airbnb-license-model\license_model.py:282, in LicenseModel.detect_and_remove_multicollinearity(self, vif_threshold, print_info)
#     274 listings_df_VIF = listings_df_VIF.astype('float64')
#     276 # calculating VIF
#     277
#     278 # Drop all rows containing NAs or infs in listings_df_VIF
#     279 # listings_df_VIF.replace([np.inf, -np.inf], np.nan, inplace=True)
#     280 # listings_df_VIF.dropna(inplace=True)
# --> 282 listings_df_VIF_new, vif_history, vif_df = drop_column_using_vif_(listings_df_VIF.drop('legal_listing', axis=1), thresh=vif_threshold, print_dropping_columns=print_info)
#     284 if print_info:
#     285     print("_" * 50)
#
# File c:\Users\SBH\OneDrive - University College London\【UCL-MSc】\#CASA0007__QuantitativeMethods\ASSESSMENT\GroupworkPresentation\yvr-airbnb-license-model\src.py:31, in drop_column_using_vif_(df, thresh, print_dropping_columns, exclude_columns)
#      27 df_with_const = add_constant(df,has_constant='add')
#      29 if 'const' in df_with_const.columns:
#      30     vif_df = pd.Series(
# ---> 31         [variance_inflation_factor(df_with_const.values, i) for i in range(df_with_const.shape[1])],
#      32         name="VIF",
#      33         index=df_with_const.columns
#      34     ).to_frame()
#      36     vif_df = vif_df.drop('const')
#      37     vif_history.append(vif_df.copy())
#
# File c:\Users\SBH\OneDrive - University College London\【UCL-MSc】\#CASA0007__QuantitativeMethods\ASSESSMENT\GroupworkPresentation\yvr-airbnb-license-model\src.py:31, in <listcomp>(.0)
#      27 df_with_const = add_constant(df,has_constant='add')
#      29 if 'const' in df_with_const.columns:
#      30     vif_df = pd.Series(
# ---> 31         [variance_inflation_factor(df_with_const.values, i) for i in range(df_with_const.shape[1])],
#      32         name="VIF",
#      33         index=df_with_const.columns
#      34     ).to_frame()
#      36     vif_df = vif_df.drop('const')
#      37     vif_history.append(vif_df.copy())
#
# File c:\Users\SBH\anaconda3\Lib\site-packages\statsmodels\stats\outliers_influence.py:197, in variance_inflation_factor(exog, exog_idx)
#     195 mask = np.arange(k_vars) != exog_idx
#     196 x_noti = exog[:, mask]
# --> 197 r_squared_i = OLS(x_i, x_noti).fit().rsquared
#     198 vif = 1. / (1. - r_squared_i)
#     199 return vif
#
# File c:\Users\SBH\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:335, in RegressionModel.fit(self, method, cov_type, cov_kwds, use_t, **kwargs)
#     330 if method == "pinv":
#     331     if not (hasattr(self, 'pinv_wexog') and
#     332             hasattr(self, 'normalized_cov_params') and
#     333             hasattr(self, 'rank')):
# --> 335         self.pinv_wexog, singular_values = pinv_extended(self.wexog)
#     336         self.normalized_cov_params = np.dot(
#     337             self.pinv_wexog, np.transpose(self.pinv_wexog))
#     339         # Cache these singular values for use later.
#
# File c:\Users\SBH\anaconda3\Lib\site-packages\statsmodels\tools\tools.py:264, in pinv_extended(x, rcond)
#     262 x = np.asarray(x)
#     263 x = x.conjugate()
# --> 264 u, s, vt = np.linalg.svd(x, False)
#     265 s_orig = np.copy(s)
#     266 m = u.shape[0]
#
# File <__array_function__ internals>:200, in svd(*args, **kwargs)
#
# File c:\Users\SBH\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:1642, in svd(a, full_matrices, compute_uv, hermitian)
#    1639         gufunc = _umath_linalg.svd_n_s
#    1641 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1642 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1643 u = u.astype(result_t, copy=False)
#    1644 s = s.astype(_realType(result_t), copy=False)
#
# KeyboardInterrupt:

# %%
# Step4 : Save coefficients to CSV
output_path = os.path.join('results', 'Toronto_airbnb_coefficients.csv')
os.makedirs(os.path.dirname(output_path), exist_ok=True)
Vancouver_airbnb_coefficients.to_csv(output_path)

print(f"\n All coefficients saved to: {output_path}")
# Out:
#  All coefficients saved to: results\Vancouver_airbnb_coefficients.csv

# %%
# step5 : Save model performance summary to CSV
performance_df = pd.DataFrame(model_performance_summary)
performance_path = os.path.join('results', 'Toronto_airbnb_model_performance.csv')
os.makedirs(os.path.dirname(performance_path), exist_ok=True)
performance_df.to_csv(performance_path, index=False)

print(f"\nAll model performance results saved to: {performance_path}")
# Out:
# All model performance results saved to: results\Vancouver_airbnb_model_performance.csv
