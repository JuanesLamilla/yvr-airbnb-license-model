# %% [markdown]
# ## Running the Control group City - Vancouver

# %% [markdown]
# **By running the Difference-in-Difference analysis, we need one control group city, this city should have following features:**
#
# 1. **Similar to the treatment group city**: The control city should have similar characteristics to the treatment city, such as population size, economic structure, and demographic profile.
#
# 2. **Not affected by the treatment**: The control city should not be directly affected by the policy changes being studied, ensuring that any differences observed can be attributed to the treatment rather than other factors.
#
# 3. **Stable over time**: The control city should have a stable trend in the outcome variable of interest before the treatment, allowing for a clear comparison with the treatment city.
#
# 4. **Geographical proximity**: Ideally, the control city should be geographically close to the treatment city to minimize external influences and ensure that both cities are subject to similar regional economic conditions, including the peak time and seasonality of the year to the STR market.
#
# Here, we use the Vancouver city as the control group city, which is similar to the treatment group city (Toronto) in terms of population size, economic structure, and demographic profile. As illustrated in the following graph.

# %%
# Load libraries
import pandas as pd
import os
import re
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import statsmodels.api as sm

sns.set_style('darkgrid')
import math
from sklearn.linear_model import LogisticRegression
from scipy import stats

import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

from license_model import LicenseModel

# %% [markdown]
# ### Iteratively run the monthly data for the control group city and get the results coefficients

# %%
import pandas as pd
import os
import numpy as np
from license_model import LicenseModel


BASE_DIR = os.path.join('data', 'Vancouver')
MONTHS = pd.date_range(start='2024-06-01', end='2025-04-01', freq='MS').strftime('%Y%m').tolist()
MIN_NIGHTS_FOR_LICENSE = 29
LICENSE_REGEX_PATTERN = r'\b\d{2}[-\s]?\d{6}\b'

# %%
# Step1 : Process each month's data and collect independent variables
all_variables = set()
protected = []

for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Vancouver',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN,
            protected_columns=protected
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()

        variables = model.logit_model.result.params.index.tolist()
        all_variables.update([v for v in variables if 'neighbourhood' not in v.lower()])

        print(f"[✓] Processed variables for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")

# Step2 : Create a DataFrame to hold coefficients for each month
Vancouver_airbnb_coefficients = pd.DataFrame(index=sorted(all_variables), columns=MONTHS)

# Step3 : Collect coefficients for each month
for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Vancouver',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()

        coef_series = model.logit_model.result.params
        coef_series = coef_series[~coef_series.index.str.contains('neighbourhood', case=False, na=False)]

        for var in coef_series.index:
            Vancouver_airbnb_coefficients.loc[var, month] = coef_series[var]

        print(f"[✓] Coefficients recorded for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")


# Step4 : Collect model performance metrics for each month
model_performance_summary = []

for month in MONTHS:
    input_file = os.path.join(BASE_DIR, month, 'listings.csv')
    if not os.path.exists(input_file):
        print(f"Missing file: {input_file}")
        continue

    try:
        model = LicenseModel(
            city='Vancouver',
            input_file=input_file,
            min_nights_for_license=MIN_NIGHTS_FOR_LICENSE,
            license_regex_pattern=LICENSE_REGEX_PATTERN
        )
        model.run_initial_setup()
        violating_vars = model.check_linearity_of_independent_variables_and_log_odds()
        for var in violating_vars:
            if var in model.listings_df.columns:
                model.listings_df.drop(columns=[var], inplace=True)

        try:
            model.check_no_strongly_influential_outliers(remove_hi_outliers=True)
        except Exception as e:
            print(f"[!] Warning during outlier removal for {month}: {e}")

        model.train_model()
        model.logit_model.evaluate_model(selected_threshold=0.5, print_info=False)

        auc = model.logit_model.auc
        acc = model.logit_model.accuracy
        pseudo_r2 = model.logit_model.result.prsquared
        one_in_ten = model.does_data_follow_one_in_ten_rule(print_info=False)
        n_predictors = model.logit_model.X_train.shape[1]
        illegal_prop = 1 - model.listings_df['legal_listing'].mean()

        model_performance_summary.append({
            'month': month,
            'AUC': auc,
            'Accuracy': acc,
            'Pseudo_R2': pseudo_r2,
            'Num_Predictors': n_predictors,
            'OneInTenRule': one_in_ten,
            'IllegalProp': illegal_prop
        })

        print(f"[✓] Model performance recorded for {month}")

    except Exception as e:
        print(f"[✗] Error processing {month}: {e}")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.198279
#          Iterations: 272
#          Function evaluations: 282
#          Gradient evaluations: 278
# [!] Warning during outlier removal for 202406: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.199504
#          Iterations: 267
#          Function evaluations: 274
#          Gradient evaluations: 274
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2644
# Model:                          Logit   Df Residuals:                     2603
# Method:                           MLE   Df Model:                           40
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1912
# Time:                        01:23:27   Log-Likelihood:                -527.49
# converged:                       True   LL-Null:                       -652.16
# Covariance Type:            nonrobust   LLR p-value:                 4.582e-32
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.6149      0.282      2.179      0.029       0.062       1.168
# host_is_superhost                                   0.2330      0.221      1.056      0.291      -0.200       0.666
# host_total_listings_count                          -0.0063      0.004     -1.763      0.078      -0.013       0.001
# bedrooms                                            0.1650      0.090      1.831      0.067      -0.012       0.341
# minimum_nights                                     -0.0131      0.024     -0.558      0.577      -0.059       0.033
# availability_30                                    -0.0349      0.022     -1.579      0.114      -0.078       0.008
# availability_90                                     0.0060      0.007      0.852      0.394      -0.008       0.020
# availability_365                                   -0.0025      0.001     -2.634      0.008      -0.004      -0.001
# number_of_reviews                                   0.0010      0.002      0.626      0.531      -0.002       0.004
# number_of_reviews_ltm                               0.0063      0.009      0.732      0.464      -0.011       0.023
# number_of_reviews_l30d                              0.1227      0.062      1.987      0.047       0.002       0.244
# review_scores_accuracy                             -0.1612      0.263     -0.612      0.540      -0.677       0.355
# review_scores_cleanliness                           0.5875      0.264      2.224      0.026       0.070       1.105
# instant_bookable                                    0.2749      0.218      1.264      0.206      -0.152       0.701
# calculated_host_listings_count_entire_homes        -0.0160      0.006     -2.470      0.014      -0.029      -0.003
# calculated_host_listings_count_private_rooms       -0.0554      0.030     -1.835      0.066      -0.115       0.004
# reviews_per_month                                  -0.0132      0.091     -0.144      0.886      -0.192       0.166
# neighbourhood_cleansed_Downtown Eastside            0.1718      0.393      0.437      0.662      -0.599       0.942
# neighbourhood_cleansed_Dunbar Southlands            0.1849      0.451      0.410      0.682      -0.698       1.068
# neighbourhood_cleansed_Fairview                     0.2287      0.763      0.300      0.765      -1.268       1.725
# neighbourhood_cleansed_Grandview-Woodland          -0.2073      0.378     -0.548      0.584      -0.949       0.534
# neighbourhood_cleansed_Hastings-Sunrise             0.0274      0.440      0.062      0.950      -0.836       0.891
# neighbourhood_cleansed_Kensington-Cedar Cottage    -0.0621      0.358     -0.174      0.862      -0.764       0.640
# neighbourhood_cleansed_Kerrisdale                   0.8558      0.799      1.071      0.284      -0.710       2.421
# neighbourhood_cleansed_Killarney                    1.4361      1.069      1.344      0.179      -0.658       3.530
# neighbourhood_cleansed_Kitsilano                    0.1116      0.403      0.277      0.782      -0.678       0.901
# neighbourhood_cleansed_Marpole                      1.4849      0.781      1.901      0.057      -0.046       3.016
# neighbourhood_cleansed_Mount Pleasant               0.6625      0.439      1.508      0.131      -0.198       1.523
# neighbourhood_cleansed_Oakridge                     0.4952      0.796      0.622      0.534      -1.065       2.056
# neighbourhood_cleansed_Renfrew-Collingwood         -0.2691      0.408     -0.660      0.509      -1.068       0.530
# neighbourhood_cleansed_Riley Park                  -0.0606      0.380     -0.160      0.873      -0.805       0.684
# neighbourhood_cleansed_Shaughnessy                  1.5724      0.809      1.944      0.052      -0.013       3.158
# neighbourhood_cleansed_South Cambie                 9.2213     75.960      0.121      0.903    -139.658     158.100
# neighbourhood_cleansed_Strathcona                  -0.1923      1.082     -0.178      0.859      -2.314       1.929
# neighbourhood_cleansed_Sunset                       1.3616      0.757      1.799      0.072      -0.122       2.845
# neighbourhood_cleansed_Victoria-Fraserview          0.8329      0.752      1.107      0.268      -0.641       2.307
# neighbourhood_cleansed_West End                    -1.0771      0.340     -3.170      0.002      -1.743      -0.411
# neighbourhood_cleansed_West Point Grey              0.4302      0.640      0.672      0.502      -0.824       1.685
# room_type_Hotel room                               -3.0336      1.329     -2.282      0.022      -5.639      -0.428
# room_type_Private room                             -0.4712      0.259     -1.819      0.069      -0.979       0.037
# room_type_Shared room                              -1.7586      1.134     -1.550      0.121      -3.982       0.465
# ===================================================================================================================
# [✓] Processed variables for 202406
# Optimization terminated successfully.
#          Current function value: 0.214311
#          Iterations: 317
#          Function evaluations: 322
#          Gradient evaluations: 322
# [!] Warning during outlier removal for 202407: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.210933
#          Iterations: 319
#          Function evaluations: 324
#          Gradient evaluations: 324
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2523
# Model:                          Logit   Df Residuals:                     2482
# Method:                           MLE   Df Model:                           40
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1828
# Time:                        01:23:30   Log-Likelihood:                -532.18
# converged:                       True   LL-Null:                       -651.23
# Covariance Type:            nonrobust   LLR p-value:                 5.347e-30
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.6468      0.281      2.298      0.022       0.095       1.199
# host_is_superhost                                   0.3170      0.210      1.511      0.131      -0.094       0.728
# host_total_listings_count                          -0.0014      0.002     -0.875      0.382      -0.004       0.002
# accommodates                                        0.0416      0.072      0.576      0.565      -0.100       0.183
# bedrooms                                            0.0039      0.140      0.028      0.978      -0.271       0.279
# minimum_nights                                     -0.0147      0.022     -0.677      0.498      -0.057       0.028
# availability_30                                    -0.0376      0.018     -2.072      0.038      -0.073      -0.002
# availability_90                                    -0.0015      0.006     -0.231      0.817      -0.014       0.011
# availability_365                                   -0.0020      0.001     -2.050      0.040      -0.004   -8.91e-05
# number_of_reviews                                   0.0018      0.002      1.133      0.257      -0.001       0.005
# number_of_reviews_l30d                              0.0966      0.064      1.507      0.132      -0.029       0.222
# review_scores_cleanliness                           0.6203      0.303      2.047      0.041       0.026       1.214
# review_scores_value                                -0.2760      0.308     -0.896      0.370      -0.880       0.328
# instant_bookable                                    0.2724      0.218      1.251      0.211      -0.154       0.699
# calculated_host_listings_count_entire_homes        -0.0205      0.004     -4.657      0.000      -0.029      -0.012
# calculated_host_listings_count_private_rooms       -0.0648      0.035     -1.847      0.065      -0.134       0.004
# reviews_per_month                                   0.1485      0.079      1.882      0.060      -0.006       0.303
# neighbourhood_cleansed_Downtown Eastside            0.1242      0.350      0.355      0.723      -0.561       0.810
# neighbourhood_cleansed_Dunbar Southlands            0.3857      0.407      0.947      0.344      -0.413       1.184
# neighbourhood_cleansed_Fairview                     0.4822      0.764      0.631      0.528      -1.015       1.980
# neighbourhood_cleansed_Grandview-Woodland           0.4741      0.413      1.149      0.251      -0.335       1.283
# neighbourhood_cleansed_Hastings-Sunrise             0.5530      0.437      1.264      0.206      -0.304       1.410
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.6136      0.373      1.646      0.100      -0.117       1.344
# neighbourhood_cleansed_Kerrisdale                   1.9187      1.058      1.814      0.070      -0.155       3.992
# neighbourhood_cleansed_Killarney                    2.0710      1.111      1.865      0.062      -0.106       4.248
# neighbourhood_cleansed_Kitsilano                    0.1955      0.340      0.576      0.565      -0.470       0.861
# neighbourhood_cleansed_Marpole                      1.5046      0.760      1.979      0.048       0.015       2.994
# neighbourhood_cleansed_Mount Pleasant               0.7616      0.433      1.759      0.079      -0.087       1.610
# neighbourhood_cleansed_Oakridge                     0.8194      0.774      1.059      0.290      -0.697       2.336
# neighbourhood_cleansed_Renfrew-Collingwood          0.4908      0.449      1.092      0.275      -0.390       1.372
# neighbourhood_cleansed_Riley Park                   0.2512      0.350      0.718      0.473      -0.435       0.937
# neighbourhood_cleansed_Shaughnessy                  1.5982      0.786      2.033      0.042       0.058       3.139
# neighbourhood_cleansed_South Cambie                14.5783    965.810      0.015      0.988   -1878.374    1907.530
# neighbourhood_cleansed_Strathcona                  -0.9329      0.751     -1.242      0.214      -2.405       0.539
# neighbourhood_cleansed_Sunset                       1.9710      1.026      1.921      0.055      -0.040       3.982
# neighbourhood_cleansed_Victoria-Fraserview          0.5544      0.637      0.871      0.384      -0.694       1.803
# neighbourhood_cleansed_West End                    -0.7343      0.380     -1.931      0.053      -1.480       0.011
# neighbourhood_cleansed_West Point Grey              1.0636      0.753      1.413      0.158      -0.412       2.539
# room_type_Hotel room                               -3.0095      1.489     -2.021      0.043      -5.928      -0.091
# room_type_Private room                             -0.5151      0.273     -1.885      0.059      -1.051       0.021
# room_type_Shared room                              -0.7673      1.794     -0.428      0.669      -4.284       2.749
# ===================================================================================================================
# [✓] Processed variables for 202407
# Optimization terminated successfully.
#          Current function value: 0.216314
#          Iterations: 283
#          Function evaluations: 291
#          Gradient evaluations: 291
# [!] Warning during outlier removal for 202408: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.210754
#          Iterations: 323
#          Function evaluations: 331
#          Gradient evaluations: 331
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2716
# Model:                          Logit   Df Residuals:                     2677
# Method:                           MLE   Df Model:                           38
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1749
# Time:                        01:23:46   Log-Likelihood:                -572.41
# converged:                       True   LL-Null:                       -693.74
# Covariance Type:            nonrobust   LLR p-value:                 1.208e-31
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.4189      0.279      1.503      0.133      -0.128       0.965
# host_is_superhost                                   0.1644      0.196      0.839      0.401      -0.220       0.549
# host_total_listings_count                          -0.0015      0.002     -1.004      0.315      -0.004       0.001
# bedrooms                                            0.1737      0.085      2.033      0.042       0.006       0.341
# minimum_nights                                     -0.0189      0.025     -0.768      0.442      -0.067       0.029
# availability_30                                    -0.0177      0.017     -1.057      0.291      -0.051       0.015
# availability_90                                    -0.0008      0.006     -0.149      0.882      -0.012       0.010
# availability_365                                   -0.0027      0.001     -2.810      0.005      -0.005      -0.001
# number_of_reviews                                   0.0031      0.001      2.168      0.030       0.000       0.006
# number_of_reviews_l30d                              0.1684      0.050      3.349      0.001       0.070       0.267
# review_scores_accuracy                              0.1888      0.270      0.699      0.484      -0.340       0.718
# review_scores_cleanliness                           0.2054      0.272      0.755      0.451      -0.328       0.739
# instant_bookable                                    0.2258      0.196      1.152      0.249      -0.158       0.610
# calculated_host_listings_count_entire_homes        -0.0206      0.005     -4.544      0.000      -0.030      -0.012
# calculated_host_listings_count_private_rooms       -0.0828      0.035     -2.363      0.018      -0.151      -0.014
# neighbourhood_cleansed_Downtown Eastside            0.4393      0.365      1.203      0.229      -0.276       1.155
# neighbourhood_cleansed_Dunbar Southlands           -0.2656      0.359     -0.740      0.459      -0.969       0.438
# neighbourhood_cleansed_Fairview                    -0.5043      0.522     -0.966      0.334      -1.528       0.519
# neighbourhood_cleansed_Grandview-Woodland           0.4405      0.429      1.026      0.305      -0.401       1.282
# neighbourhood_cleansed_Hastings-Sunrise             0.4776      0.426      1.122      0.262      -0.357       1.312
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.3960      0.344      1.150      0.250      -0.279       1.071
# neighbourhood_cleansed_Kerrisdale                   1.5406      1.061      1.452      0.146      -0.538       3.620
# neighbourhood_cleansed_Killarney                    1.6105      1.046      1.539      0.124      -0.440       3.661
# neighbourhood_cleansed_Kitsilano                    0.2543      0.352      0.722      0.470      -0.436       0.945
# neighbourhood_cleansed_Marpole                      1.5717      0.776      2.027      0.043       0.052       3.092
# neighbourhood_cleansed_Mount Pleasant               0.9927      0.450      2.208      0.027       0.111       1.874
# neighbourhood_cleansed_Oakridge                     0.0618      0.568      0.109      0.913      -1.052       1.176
# neighbourhood_cleansed_Renfrew-Collingwood          0.5420      0.497      1.091      0.275      -0.432       1.516
# neighbourhood_cleansed_Riley Park                   0.0073      0.345      0.021      0.983      -0.669       0.684
# neighbourhood_cleansed_Shaughnessy                  0.5638      0.551      1.023      0.306      -0.517       1.644
# neighbourhood_cleansed_South Cambie                11.5643    223.508      0.052      0.959    -426.504     449.633
# neighbourhood_cleansed_Strathcona                  -0.4636      0.761     -0.609      0.542      -1.955       1.027
# neighbourhood_cleansed_Sunset                       2.3147      1.022      2.265      0.023       0.312       4.317
# neighbourhood_cleansed_Victoria-Fraserview          1.2896      0.745      1.732      0.083      -0.170       2.749
# neighbourhood_cleansed_West End                    -0.9396      0.337     -2.785      0.005      -1.601      -0.278
# neighbourhood_cleansed_West Point Grey              0.7961      0.752      1.058      0.290      -0.678       2.270
# room_type_Hotel room                               -2.3615      1.473     -1.603      0.109      -5.249       0.526
# room_type_Private room                             -0.2338      0.253     -0.926      0.355      -0.729       0.261
# room_type_Shared room                              -0.4492      1.667     -0.269      0.788      -3.716       2.818
# ===================================================================================================================
# [✓] Processed variables for 202408
# Optimization terminated successfully.
#          Current function value: 0.211990
#          Iterations: 358
#          Function evaluations: 366
#          Gradient evaluations: 366
# [!] Warning during outlier removal for 202409: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.204552
#          Iterations: 330
#          Function evaluations: 339
#          Gradient evaluations: 339
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2596
# Model:                          Logit   Df Residuals:                     2555
# Method:                           MLE   Df Model:                           40
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.2038
# Time:                        01:24:04   Log-Likelihood:                -531.02
# converged:                       True   LL-Null:                       -666.90
# Covariance Type:            nonrobust   LLR p-value:                 3.138e-36
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.2960      0.289      1.024      0.306      -0.270       0.862
# host_is_superhost                                   0.4227      0.212      1.991      0.047       0.007       0.839
# host_total_listings_count                          -0.0010      0.001     -0.712      0.476      -0.004       0.002
# bedrooms                                            0.1331      0.088      1.517      0.129      -0.039       0.305
# minimum_nights                                     -0.0349      0.021     -1.656      0.098      -0.076       0.006
# availability_30                                    -0.0263      0.016     -1.650      0.099      -0.057       0.005
# availability_90                                     0.0034      0.006      0.604      0.546      -0.008       0.014
# availability_365                                   -0.0023      0.001     -2.391      0.017      -0.004      -0.000
# number_of_reviews                               -1.352e-05      0.001     -0.010      0.992      -0.003       0.003
# number_of_reviews_l30d                              0.1137      0.062      1.824      0.068      -0.008       0.236
# review_scores_accuracy                              0.3019      0.330      0.916      0.360      -0.344       0.948
# review_scores_cleanliness                           0.2359      0.314      0.751      0.453      -0.380       0.852
# review_scores_value                                -0.1268      0.322     -0.394      0.694      -0.758       0.504
# instant_bookable                                   -0.0265      0.206     -0.129      0.897      -0.430       0.377
# calculated_host_listings_count_entire_homes        -0.0203      0.004     -4.703      0.000      -0.029      -0.012
# calculated_host_listings_count_private_rooms       -0.0701      0.034     -2.054      0.040      -0.137      -0.003
# reviews_per_month                                   0.1535      0.078      1.976      0.048       0.001       0.306
# neighbourhood_cleansed_Downtown Eastside            0.4315      0.389      1.109      0.267      -0.331       1.194
# neighbourhood_cleansed_Dunbar Southlands            0.3227      0.398      0.812      0.417      -0.456       1.102
# neighbourhood_cleansed_Fairview                    -0.2602      0.537     -0.485      0.628      -1.312       0.792
# neighbourhood_cleansed_Grandview-Woodland           0.7890      0.497      1.586      0.113      -0.186       1.764
# neighbourhood_cleansed_Hastings-Sunrise             0.6455      0.462      1.396      0.163      -0.261       1.552
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.1722      0.327      0.527      0.598      -0.468       0.813
# neighbourhood_cleansed_Kerrisdale                   1.6308      1.066      1.530      0.126      -0.458       3.720
# neighbourhood_cleansed_Killarney                    1.3660      1.049      1.302      0.193      -0.690       3.422
# neighbourhood_cleansed_Kitsilano                    0.5110      0.369      1.386      0.166      -0.211       1.233
# neighbourhood_cleansed_Marpole                      1.8668      0.774      2.411      0.016       0.349       3.384
# neighbourhood_cleansed_Mount Pleasant               0.9141      0.444      2.058      0.040       0.044       1.784
# neighbourhood_cleansed_Oakridge                     0.6242      0.622      1.004      0.315      -0.594       1.843
# neighbourhood_cleansed_Renfrew-Collingwood          0.1733      0.423      0.410      0.682      -0.656       1.002
# neighbourhood_cleansed_Riley Park                  -0.0618      0.337     -0.184      0.854      -0.722       0.598
# neighbourhood_cleansed_Shaughnessy                  1.1703      0.557      2.103      0.035       0.080       2.261
# neighbourhood_cleansed_South Cambie                25.1894   2.33e+05      0.000      1.000   -4.57e+05    4.57e+05
# neighbourhood_cleansed_Strathcona                  -0.6729      0.899     -0.748      0.454      -2.435       1.089
# neighbourhood_cleansed_Sunset                       2.3958      1.036      2.313      0.021       0.366       4.426
# neighbourhood_cleansed_Victoria-Fraserview          1.1844      0.749      1.582      0.114      -0.283       2.652
# neighbourhood_cleansed_West End                    -0.3680      0.381     -0.965      0.334      -1.115       0.379
# neighbourhood_cleansed_West Point Grey              2.1568      1.068      2.019      0.044       0.063       4.251
# room_type_Hotel room                               11.3007    891.377      0.013      0.990   -1735.766    1758.367
# room_type_Private room                             -0.8829      0.245     -3.608      0.000      -1.362      -0.403
# room_type_Shared room                              -1.6643      2.261     -0.736      0.462      -6.096       2.768
# ===================================================================================================================
# [✓] Processed variables for 202409
# Optimization terminated successfully.
#          Current function value: 0.208312
#          Iterations: 276
#          Function evaluations: 282
#          Gradient evaluations: 282
# [!] Warning during outlier removal for 202410: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.209296
#          Iterations: 274
#          Function evaluations: 282
#          Gradient evaluations: 282
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2712
# Model:                          Logit   Df Residuals:                     2674
# Method:                           MLE   Df Model:                           37
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.2213
# Time:                        01:24:33   Log-Likelihood:                -567.61
# converged:                       True   LL-Null:                       -728.95
# Covariance Type:            nonrobust   LLR p-value:                 2.761e-47
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.3027      0.275      1.099      0.272      -0.237       0.842
# host_is_superhost                                   0.4795      0.199      2.406      0.016       0.089       0.870
# host_total_listings_count                          -0.0053      0.004     -1.415      0.157      -0.013       0.002
# bedrooms                                            0.0986      0.080      1.232      0.218      -0.058       0.255
# minimum_nights                                     -0.0294      0.021     -1.414      0.157      -0.070       0.011
# availability_30                                    -0.0105      0.010     -1.107      0.268      -0.029       0.008
# availability_365                                   -0.0023      0.001     -2.814      0.005      -0.004      -0.001
# number_of_reviews                                  -0.0008      0.001     -0.652      0.515      -0.003       0.002
# number_of_reviews_l30d                              0.1099      0.061      1.813      0.070      -0.009       0.229
# review_scores_accuracy                              0.3918      0.061      6.401      0.000       0.272       0.512
# instant_bookable                                    0.1328      0.202      0.657      0.511      -0.264       0.529
# calculated_host_listings_count_entire_homes        -0.0126      0.006     -1.967      0.049      -0.025    -4.8e-05
# calculated_host_listings_count_private_rooms       -0.0597      0.026     -2.277      0.023      -0.111      -0.008
# reviews_per_month                                   0.2008      0.077      2.616      0.009       0.050       0.351
# neighbourhood_cleansed_Downtown Eastside            0.4809      0.371      1.297      0.195      -0.246       1.208
# neighbourhood_cleansed_Dunbar Southlands            0.6312      0.395      1.597      0.110      -0.144       1.406
# neighbourhood_cleansed_Fairview                     0.3623      0.643      0.564      0.573      -0.897       1.622
# neighbourhood_cleansed_Grandview-Woodland           0.9504      0.457      2.081      0.037       0.055       1.845
# neighbourhood_cleansed_Hastings-Sunrise             0.7150      0.458      1.561      0.119      -0.183       1.613
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.2695      0.326      0.827      0.408      -0.369       0.908
# neighbourhood_cleansed_Kerrisdale                   0.3756      0.641      0.586      0.558      -0.880       1.631
# neighbourhood_cleansed_Killarney                    2.1146      1.059      1.997      0.046       0.040       4.190
# neighbourhood_cleansed_Kitsilano                    0.5206      0.352      1.480      0.139      -0.169       1.210
# neighbourhood_cleansed_Marpole                      1.5637      0.648      2.413      0.016       0.294       2.834
# neighbourhood_cleansed_Mount Pleasant               1.7763      0.481      3.691      0.000       0.833       2.719
# neighbourhood_cleansed_Oakridge                     0.5163      0.549      0.941      0.347      -0.559       1.592
# neighbourhood_cleansed_Renfrew-Collingwood          0.4770      0.422      1.130      0.259      -0.351       1.305
# neighbourhood_cleansed_Riley Park                   0.2126      0.344      0.618      0.536      -0.461       0.886
# neighbourhood_cleansed_Shaughnessy                  1.1081      0.572      1.937      0.053      -0.013       2.230
# neighbourhood_cleansed_South Cambie                11.6578    212.701      0.055      0.956    -405.228     428.543
# neighbourhood_cleansed_Strathcona                   0.4548      1.266      0.359      0.719      -2.026       2.936
# neighbourhood_cleansed_Sunset                       1.3997      0.623      2.246      0.025       0.178       2.621
# neighbourhood_cleansed_Victoria-Fraserview          1.4249      0.745      1.914      0.056      -0.034       2.884
# neighbourhood_cleansed_West End                    -0.5814      0.320     -1.815      0.070      -1.209       0.046
# neighbourhood_cleansed_West Point Grey              2.1601      0.721      2.995      0.003       0.747       3.574
# room_type_Hotel room                              -19.8318   3797.752     -0.005      0.996   -7463.289    7423.625
# room_type_Private room                             -1.1053      0.216     -5.127      0.000      -1.528      -0.683
# room_type_Shared room                               0.2238      1.284      0.174      0.862      -2.292       2.740
# ===================================================================================================================
# [✓] Processed variables for 202410
# Optimization terminated successfully.
#          Current function value: 0.215205
#          Iterations: 299
#          Function evaluations: 306
#          Gradient evaluations: 306
# [!] Warning during outlier removal for 202411: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.216817
#          Iterations: 281
#          Function evaluations: 288
#          Gradient evaluations: 288
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2738
# Model:                          Logit   Df Residuals:                     2697
# Method:                           MLE   Df Model:                           40
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.2042
# Time:                        01:24:58   Log-Likelihood:                -593.65
# converged:                       True   LL-Null:                       -745.95
# Covariance Type:            nonrobust   LLR p-value:                 1.987e-42
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.2887      0.268      1.079      0.281      -0.236       0.813
# host_is_superhost                                   0.3596      0.195      1.842      0.065      -0.023       0.742
# host_total_listings_count                          -0.0054      0.004     -1.473      0.141      -0.013       0.002
# bedrooms                                            0.1098      0.081      1.349      0.177      -0.050       0.269
# minimum_nights                                      0.0042      0.030      0.141      0.888      -0.054       0.062
# availability_30                                    -0.0144      0.015     -0.939      0.347      -0.044       0.016
# availability_90                                     0.0002      0.006      0.040      0.968      -0.011       0.011
# availability_365                                   -0.0022      0.001     -2.350      0.019      -0.004      -0.000
# number_of_reviews                                   0.0008      0.001      0.621      0.534      -0.002       0.003
# number_of_reviews_l30d                              0.0239      0.071      0.335      0.738      -0.116       0.164
# review_scores_cleanliness                           0.3200      0.211      1.519      0.129      -0.093       0.733
# review_scores_checkin                              -0.4166      0.274     -1.521      0.128      -0.953       0.120
# review_scores_communication                         0.4831      0.310      1.560      0.119      -0.124       1.090
# instant_bookable                                   -0.0081      0.193     -0.042      0.966      -0.386       0.370
# calculated_host_listings_count_entire_homes        -0.0113      0.006     -1.805      0.071      -0.024       0.001
# calculated_host_listings_count_private_rooms       -0.0219      0.022     -0.998      0.318      -0.065       0.021
# reviews_per_month                                   0.2000      0.075      2.661      0.008       0.053       0.347
# neighbourhood_cleansed_Downtown Eastside            0.7564      0.380      1.993      0.046       0.012       1.501
# neighbourhood_cleansed_Dunbar Southlands            0.8439      0.420      2.011      0.044       0.021       1.667
# neighbourhood_cleansed_Fairview                     0.1653      0.634      0.261      0.794      -1.077       1.408
# neighbourhood_cleansed_Grandview-Woodland           1.3342      0.544      2.454      0.014       0.269       2.400
# neighbourhood_cleansed_Hastings-Sunrise             0.6596      0.408      1.616      0.106      -0.140       1.460
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.4520      0.338      1.339      0.181      -0.210       1.114
# neighbourhood_cleansed_Kerrisdale                  -0.1335      0.627     -0.213      0.831      -1.362       1.095
# neighbourhood_cleansed_Killarney                   11.2565    101.274      0.111      0.911    -187.238     209.751
# neighbourhood_cleansed_Kitsilano                    0.2326      0.327      0.711      0.477      -0.409       0.874
# neighbourhood_cleansed_Marpole                      1.8995      0.761      2.496      0.013       0.408       3.391
# neighbourhood_cleansed_Mount Pleasant               1.7704      0.525      3.371      0.001       0.741       2.800
# neighbourhood_cleansed_Oakridge                     0.6062      0.553      1.097      0.273      -0.477       1.690
# neighbourhood_cleansed_Renfrew-Collingwood          0.6641      0.431      1.542      0.123      -0.180       1.508
# neighbourhood_cleansed_Riley Park                   0.2087      0.339      0.615      0.539      -0.457       0.874
# neighbourhood_cleansed_Shaughnessy                  1.0514      0.491      2.141      0.032       0.089       2.014
# neighbourhood_cleansed_South Cambie                10.0275     97.482      0.103      0.918    -181.034     201.090
# neighbourhood_cleansed_Strathcona                  -0.8668      0.961     -0.902      0.367      -2.751       1.017
# neighbourhood_cleansed_Sunset                       1.1591      0.548      2.115      0.034       0.085       2.233
# neighbourhood_cleansed_Victoria-Fraserview          1.4343      0.741      1.936      0.053      -0.018       2.887
# neighbourhood_cleansed_West End                    -0.9869      0.299     -3.306      0.001      -1.572      -0.402
# neighbourhood_cleansed_West Point Grey              1.6308      0.681      2.393      0.017       0.295       2.966
# room_type_Hotel room                               -3.5101      1.313     -2.672      0.008      -6.084      -0.936
# room_type_Private room                             -0.8957      0.212     -4.233      0.000      -1.310      -0.481
# room_type_Shared room                               0.3305      1.201      0.275      0.783      -2.023       2.684
# ===================================================================================================================
# [✓] Processed variables for 202411
# Optimization terminated successfully.
#          Current function value: 0.216125
#          Iterations: 322
#          Function evaluations: 330
#          Gradient evaluations: 330
# [!] Warning during outlier removal for 202412: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.211894
#          Iterations: 300
#          Function evaluations: 307
#          Gradient evaluations: 307
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2784
# Model:                          Logit   Df Residuals:                     2742
# Method:                           MLE   Df Model:                           41
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.2024
# Time:                        01:25:23   Log-Likelihood:                -589.91
# converged:                       True   LL-Null:                       -739.60
# Covariance Type:            nonrobust   LLR p-value:                 5.423e-41
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.3025      0.259      1.169      0.242      -0.205       0.810
# host_is_superhost                                   0.4569      0.197      2.323      0.020       0.071       0.842
# host_total_listings_count                          -0.0121      0.005     -2.527      0.011      -0.022      -0.003
# bedrooms                                            0.0886      0.090      0.986      0.324      -0.087       0.265
# minimum_nights                                      0.1071      0.055      1.960      0.050    1.75e-05       0.214
# availability_30                                    -0.0057      0.014     -0.392      0.695      -0.034       0.023
# availability_90                                     0.0066      0.005      1.259      0.208      -0.004       0.017
# availability_365                                   -0.0032      0.001     -3.474      0.001      -0.005      -0.001
# number_of_reviews                                   0.0011      0.001      0.795      0.427      -0.002       0.004
# number_of_reviews_l30d                              0.0078      0.065      0.121      0.904      -0.119       0.135
# review_scores_cleanliness                           0.1803      0.279      0.647      0.517      -0.366       0.726
# review_scores_checkin                              -0.4330      0.297     -1.459      0.145      -1.015       0.149
# review_scores_communication                         0.1880      0.281      0.670      0.503      -0.362       0.738
# review_scores_value                                 0.3323      0.311      1.068      0.286      -0.278       0.942
# instant_bookable                                   -0.0224      0.190     -0.118      0.906      -0.395       0.350
# calculated_host_listings_count_entire_homes         0.0028      0.008      0.341      0.733      -0.013       0.019
# calculated_host_listings_count_private_rooms       -0.0012      0.026     -0.045      0.964      -0.052       0.050
# reviews_per_month                                   0.2082      0.077      2.718      0.007       0.058       0.358
# neighbourhood_cleansed_Downtown Eastside            0.8464      0.377      2.247      0.025       0.108       1.585
# neighbourhood_cleansed_Dunbar Southlands            1.1811      0.440      2.683      0.007       0.318       2.044
# neighbourhood_cleansed_Fairview                     0.4817      0.636      0.757      0.449      -0.766       1.729
# neighbourhood_cleansed_Grandview-Woodland           1.0031      0.458      2.192      0.028       0.106       1.900
# neighbourhood_cleansed_Hastings-Sunrise             1.0146      0.427      2.376      0.018       0.178       1.852
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.8557      0.332      2.578      0.010       0.205       1.506
# neighbourhood_cleansed_Kerrisdale                   0.6600      0.656      1.006      0.315      -0.626       1.946
# neighbourhood_cleansed_Killarney                   39.2079   4.65e+07   8.43e-07      1.000   -9.11e+07    9.11e+07
# neighbourhood_cleansed_Kitsilano                    0.4430      0.328      1.350      0.177      -0.200       1.086
# neighbourhood_cleansed_Marpole                      1.6463      0.638      2.582      0.010       0.397       2.896
# neighbourhood_cleansed_Mount Pleasant               1.5438      0.436      3.539      0.000       0.689       2.399
# neighbourhood_cleansed_Oakridge                     0.6655      0.503      1.323      0.186      -0.320       1.651
# neighbourhood_cleansed_Renfrew-Collingwood          1.1210      0.471      2.380      0.017       0.198       2.044
# neighbourhood_cleansed_Riley Park                   0.2039      0.322      0.633      0.527      -0.428       0.835
# neighbourhood_cleansed_Shaughnessy                  2.5260      0.685      3.685      0.000       1.183       3.869
# neighbourhood_cleansed_South Cambie                39.0878   1.27e+08   3.07e-07      1.000   -2.49e+08    2.49e+08
# neighbourhood_cleansed_Strathcona                   0.8322      1.225      0.679      0.497      -1.569       3.234
# neighbourhood_cleansed_Sunset                       2.0046      0.743      2.699      0.007       0.549       3.460
# neighbourhood_cleansed_Victoria-Fraserview          1.4094      0.624      2.258      0.024       0.186       2.633
# neighbourhood_cleansed_West End                    -0.1679      0.322     -0.522      0.602      -0.798       0.462
# neighbourhood_cleansed_West Point Grey              2.3212      0.811      2.861      0.004       0.731       3.911
# room_type_Hotel room                               -3.2692      1.327     -2.463      0.014      -5.871      -0.668
# room_type_Private room                             -1.0862      0.214     -5.081      0.000      -1.505      -0.667
# room_type_Shared room                               4.3953     54.278      0.081      0.935    -101.987     110.778
# ===================================================================================================================
# [✓] Processed variables for 202412
# Optimization terminated successfully.
#          Current function value: 0.224636
#          Iterations: 331
#          Function evaluations: 338
#          Gradient evaluations: 338
# [!] Warning during outlier removal for 202501: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.225553
#          Iterations: 330
#          Function evaluations: 335
#          Gradient evaluations: 335
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2704
# Model:                          Logit   Df Residuals:                     2664
# Method:                           MLE   Df Model:                           39
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1901
# Time:                        01:25:52   Log-Likelihood:                -609.90
# converged:                       True   LL-Null:                       -753.01
# Covariance Type:            nonrobust   LLR p-value:                 2.202e-39
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.5179      0.256      2.022      0.043       0.016       1.020
# host_is_superhost                                   0.4031      0.199      2.028      0.043       0.013       0.793
# bedrooms                                            0.0656      0.082      0.803      0.422      -0.094       0.226
# minimum_nights                                     -0.0072      0.030     -0.240      0.810      -0.066       0.052
# availability_30                                    -0.0062      0.009     -0.721      0.471      -0.023       0.011
# availability_365                                   -0.0020      0.001     -2.458      0.014      -0.004      -0.000
# number_of_reviews                                   0.0006      0.001      0.489      0.625      -0.002       0.003
# number_of_reviews_l30d                             -0.0636      0.077     -0.826      0.409      -0.215       0.087
# review_scores_cleanliness                           0.3443      0.271      1.268      0.205      -0.188       0.876
# review_scores_checkin                              -0.7736      0.289     -2.673      0.008      -1.341      -0.206
# review_scores_communication                         0.2442      0.273      0.895      0.371      -0.291       0.779
# review_scores_value                                 0.5705      0.302      1.888      0.059      -0.022       1.163
# instant_bookable                                    0.0268      0.191      0.140      0.888      -0.347       0.400
# calculated_host_listings_count_entire_homes        -0.0187      0.004     -5.109      0.000      -0.026      -0.012
# ...
# calculated_host_listings_count_private_rooms        0.0252        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Downtown Eastside            1.2056        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Dunbar Southlands            0.2966        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Fairview                     1.5535        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Grandview-Woodland           0.4505        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Hastings-Sunrise             1.0328        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kensington-Cedar Cottage     1.5153        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kerrisdale                  -0.3104        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Killarney                   36.5990        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Kitsilano                    0.6611        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Marpole                      1.6222        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Mount Pleasant               1.1316        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Oakridge                     1.0279        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Renfrew-Collingwood          0.6063        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Riley Park                   0.9589        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Shaughnessy                  1.6608        nan        nan        nan         nan         nan
# neighbourhood_cleansed_South Cambie                32.5022        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Strathcona                   0.0883        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Sunset                       0.7035        nan        nan        nan         nan         nan
# neighbourhood_cleansed_Victoria-Fraserview          0.9315        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West End                    -0.6055        nan        nan        nan         nan         nan
# neighbourhood_cleansed_West Point Grey              1.1802        nan        nan        nan         nan         nan
# room_type_Hotel room                              -45.3299        nan        nan        nan         nan         nan
# room_type_Private room                             -0.9940        nan        nan        nan         nan         nan
# room_type_Shared room                               5.0223        nan        nan        nan         nan         nan
# ===================================================================================================================
# [✗] Error processing 202502: LogitModel.evaluate_model() got an unexpected keyword argument 'print_info'
# Optimization terminated successfully.
#          Current function value: 0.219933
#          Iterations: 282
#          Function evaluations: 289
#          Gradient evaluations: 289
# [!] Warning during outlier removal for 202503: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.221607
#          Iterations: 265
#          Function evaluations: 275
#          Gradient evaluations: 275
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 1496
# Model:                          Logit   Df Residuals:                     1457
# Method:                           MLE   Df Model:                           38
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1338
# Time:                        01:36:18   Log-Likelihood:                -331.52
# converged:                       True   LL-Null:                       -382.75
# Covariance Type:            nonrobust   LLR p-value:                 7.938e-08
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.9267      0.341      2.714      0.007       0.258       1.596
# host_is_superhost                                  -0.2142      0.292     -0.735      0.462      -0.786       0.357
# host_total_listings_count                          -0.0045      0.004     -1.268      0.205      -0.011       0.002
# bedrooms                                           -0.0311      0.100     -0.312      0.755      -0.226       0.164
# minimum_nights                                     -0.0002      0.044     -0.006      0.996      -0.086       0.086
# availability_30                                     0.0073      0.014      0.524      0.601      -0.020       0.035
# availability_365                                   -0.0013      0.001     -1.055      0.291      -0.004       0.001
# number_of_reviews                                   0.0011      0.002      0.586      0.558      -0.003       0.005
# number_of_reviews_l30d                             -0.0131      0.078     -0.167      0.867      -0.167       0.140
# estimated_occupancy_l365d                           0.0020      0.002      1.076      0.282      -0.002       0.006
# review_scores_cleanliness                           0.1155      0.406      0.284      0.776      -0.681       0.912
# review_scores_value                                 0.3042      0.414      0.734      0.463      -0.508       1.116
# instant_bookable                                   -0.0767      0.261     -0.294      0.769      -0.588       0.434
# calculated_host_listings_count_entire_homes        -0.0367      0.015     -2.403      0.016      -0.067      -0.007
# calculated_host_listings_count_private_rooms       -0.1296      0.127     -1.019      0.308      -0.379       0.120
# neighbourhood_cleansed_Downtown Eastside            0.6226      0.471      1.323      0.186      -0.300       1.545
# neighbourhood_cleansed_Dunbar Southlands           -0.3975      0.510     -0.780      0.435      -1.397       0.602
# neighbourhood_cleansed_Fairview                    -0.2221      0.801     -0.277      0.782      -1.792       1.348
# neighbourhood_cleansed_Grandview-Woodland           0.3363      0.518      0.649      0.517      -0.680       1.353
# neighbourhood_cleansed_Hastings-Sunrise             0.2195      0.476      0.461      0.645      -0.714       1.153
# neighbourhood_cleansed_Kensington-Cedar Cottage     0.7429      0.509      1.460      0.144      -0.254       1.740
# neighbourhood_cleansed_Kerrisdale                  -0.2093      1.062     -0.197      0.844      -2.291       1.873
# neighbourhood_cleansed_Killarney                   51.6819   5.12e+07   1.01e-06      1.000      -1e+08       1e+08
# neighbourhood_cleansed_Kitsilano                    0.7196      0.528      1.363      0.173      -0.315       1.755
# neighbourhood_cleansed_Marpole                      0.6438      0.774      0.832      0.405      -0.873       2.161
# neighbourhood_cleansed_Mount Pleasant               0.7776      0.598      1.301      0.193      -0.394       1.949
# neighbourhood_cleansed_Oakridge                     0.8969      1.049      0.855      0.393      -1.159       2.953
# neighbourhood_cleansed_Renfrew-Collingwood          0.7295      0.486      1.501      0.133      -0.223       1.682
# neighbourhood_cleansed_Riley Park                  -0.2420      0.518     -0.467      0.641      -1.258       0.774
# neighbourhood_cleansed_Shaughnessy                  0.9640      1.160      0.831      0.406      -1.310       3.238
# neighbourhood_cleansed_South Cambie                42.7324   3.85e+07   1.11e-06      1.000   -7.54e+07    7.54e+07
# neighbourhood_cleansed_Strathcona                   0.5046      1.257      0.402      0.688      -1.958       2.968
# neighbourhood_cleansed_Sunset                       1.1210      1.055      1.063      0.288      -0.946       3.188
# neighbourhood_cleansed_Victoria-Fraserview          0.2825      0.647      0.437      0.662      -0.986       1.551
# neighbourhood_cleansed_West End                    -0.0665      0.488     -0.136      0.891      -1.022       0.889
# neighbourhood_cleansed_West Point Grey              0.5061      1.119      0.452      0.651      -1.687       2.700
# room_type_Hotel room                               -1.4338      1.527     -0.939      0.348      -4.427       1.560
# room_type_Private room                             -1.2835      0.423     -3.032      0.002      -2.113      -0.454
# room_type_Shared room                             -36.4721   3.85e+07  -9.47e-07      1.000   -7.54e+07    7.54e+07
# ===================================================================================================================
# [✗] Error processing 202503: LogitModel.evaluate_model() got an unexpected keyword argument 'print_info'
# Optimization terminated successfully.
#          Current function value: 0.209209
#          Iterations: 308
#          Function evaluations: 315
#          Gradient evaluations: 315
# [!] Warning during outlier removal for 202504: cannot access local variable 'influential_outliers' where it is not associated with a value
# Optimization terminated successfully.
#          Current function value: 0.217043
#          Iterations: 304
#          Function evaluations: 314
#          Gradient evaluations: 314
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:          legal_listing   No. Observations:                 2413
# Model:                          Logit   Df Residuals:                     2372
# Method:                           MLE   Df Model:                           40
# Date:                Tue, 10 Jun 2025   Pseudo R-squ.:                  0.1518
# Time:                        01:36:22   Log-Likelihood:                -523.72
# converged:                       True   LL-Null:                       -617.42
# Covariance Type:            nonrobust   LLR p-value:                 6.054e-21
# ===================================================================================================================
#                                                       coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------
# host_response_time                                  0.2358      0.290      0.813      0.416      -0.332       0.804
# host_is_superhost                                   0.0871      0.209      0.416      0.677      -0.323       0.497
# host_total_listings_count                          -0.0088      0.005     -1.752      0.080      -0.019       0.001
# bedrooms                                           -0.1312      0.084     -1.568      0.117      -0.295       0.033
# minimum_nights                                     -0.0040      0.039     -0.102      0.918      -0.080       0.072
# availability_30                                     0.0171      0.011      1.512      0.130      -0.005       0.039
# availability_365                                   -0.0027      0.001     -2.974      0.003      -0.005      -0.001
# number_of_reviews                                   0.0007      0.001      0.484      0.628      -0.002       0.003
# number_of_reviews_l30d                             -0.1167      0.048     -2.414      0.016      -0.211      -0.022
# estimated_occupancy_l365d                           0.0047      0.002      2.798      0.005       0.001       0.008
# review_scores_cleanliness                           0.1536      0.344      0.446      0.656      -0.521       0.829
# review_scores_communication                        -0.0402      0.286     -0.140      0.888      -0.601       0.521
# review_scores_value                                 0.3389      0.339      0.998      0.318      -0.326       1.004
# instant_bookable                                   -0.2016      0.198     -1.020      0.308      -0.589       0.186
# calculated_host_listings_count_entire_homes        -0.0011      0.008     -0.139      0.890      -0.017       0.015
# calculated_host_listings_count_private_rooms        0.2852      0.072      3.955      0.000       0.144       0.427
# reviews_per_month                                   0.0797      0.092      0.865      0.387      -0.101       0.260
# neighbourhood_cleansed_Downtown Eastside            0.3075      0.367      0.839      0.402      -0.411       1.026
# neighbourhood_cleansed_Dunbar Southlands            0.5320      0.419      1.268      0.205      -0.290       1.354
# neighbourhood_cleansed_Fairview                     0.4398      0.775      0.568      0.570      -1.078       1.958
# neighbourhood_cleansed_Grandview-Woodland           0.9654      0.493      1.956      0.050      -0.002       1.933
# neighbourhood_cleansed_Hastings-Sunrise             1.1483      0.492      2.335      0.020       0.184       2.112
# neighbourhood_cleansed_Kensington-Cedar Cottage     1.4286      0.487      2.930      0.003       0.473       2.384
# neighbourhood_cleansed_Kerrisdale                   0.1535      0.799      0.192      0.848      -1.413       1.720
# neighbourhood_cleansed_Killarney                   12.0208    140.255      0.086      0.932    -262.874     286.915
# neighbourhood_cleansed_Kitsilano                    0.3441      0.336      1.025      0.305      -0.314       1.002
# neighbourhood_cleansed_Marpole                      1.8068      0.760      2.379      0.017       0.318       3.295
# neighbourhood_cleansed_Mount Pleasant               1.2908      0.537      2.406      0.016       0.239       2.342
# neighbourhood_cleansed_Oakridge                     1.2863      0.759      1.695      0.090      -0.201       2.774
# neighbourhood_cleansed_Renfrew-Collingwood          0.3064      0.375      0.816      0.414      -0.429       1.042
# neighbourhood_cleansed_Riley Park                   0.6040      0.401      1.508      0.132      -0.181       1.389
# neighbourhood_cleansed_Shaughnessy                  0.5313      0.539      0.986      0.324      -0.525       1.587
# neighbourhood_cleansed_South Cambie                12.0624    227.507      0.053      0.958    -433.844     457.968
# neighbourhood_cleansed_Strathcona                  -1.5066      0.895     -1.682      0.092      -3.262       0.249
# neighbourhood_cleansed_Sunset                       0.9997      0.619      1.616      0.106      -0.213       2.212
# neighbourhood_cleansed_Victoria-Fraserview          0.3313      0.509      0.651      0.515      -0.666       1.328
# neighbourhood_cleansed_West End                    -0.8288      0.363     -2.284      0.022      -1.540      -0.117
# neighbourhood_cleansed_West Point Grey              0.9986      0.756      1.320      0.187      -0.484       2.481
# room_type_Hotel room                               -3.0160      1.312     -2.299      0.022      -5.588      -0.445
# room_type_Private room                             -1.6562      0.279     -5.942      0.000      -2.203      -1.110
# room_type_Shared room                              -2.7414      1.577     -1.738      0.082      -5.832       0.349
# ===================================================================================================================
# [✗] Error processing 202504: LogitModel.evaluate_model() got an unexpected keyword argument 'print_info'

# %%
# Step4 : Save coefficients to CSV
output_path = os.path.join('results', 'Vancouver_airbnb_coefficients.csv')
os.makedirs(os.path.dirname(output_path), exist_ok=True)
Vancouver_airbnb_coefficients.to_csv(output_path)

print(f"\n All coefficients saved to: {output_path}")
# Out:
#  All coefficients saved to: results\Vancouver_airbnb_coefficients.csv

# %%
# Step5 : Save model performance summary to CSV
performance_df = pd.DataFrame(model_performance_summary)
performance_path = os.path.join('results', 'Vancouver_airbnb_model_performance.csv')
os.makedirs(os.path.dirname(performance_path), exist_ok=True)
performance_df.to_csv(performance_path, index=False)

print(f"\nAll model performance results saved to: {performance_path}")
# Out:
# All model performance results saved to: results\Vancouver_airbnb_model_performance.csv
